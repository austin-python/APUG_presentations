# %% [markdown]
# # Austin Python Users Group
#
# ## Let's make this meetup better!
#
# ### Danny Mulligan - 2019-05-08
#
# ____
# ### Insert github link here
# ____

# %% [markdown]
# This is NOT intended as criticism of previous meetups, presentations, organziers, etc.
#
# APUG has been a valuable meetup for all of us over the past years, how can we make it better?

# %% [markdown]
# # Social Benefits
#
# ### Arguably the biggest benefit of this group
# - Come for the presentations, but stay for the people
#
# ### What can we do to help hire + be hired?
# - Senior people coaching / mentoring junior?
# - "Help me find a job" / "Help me find someone to do X"
# - Make me a more valuable / useful contributor in my current job
#
# ### What can we do to make our group be more approacable by new members?
# - Can we be more welcoming for first timer attendees?
# - How can we do to attract more people on the web?
# - Name tags?  Signage?  Friendliness?
# - Adopt an Introvert night
# ![Joke/Not Joke](How-introverts-make-friends.png "How Introverts Make Friends")
#
# ### Need more people helping organize!
# - Communication
# - Food + drinks
# - Presentation content
# - Dealing with sponsors
#
# ### Need better communication
# - Presentation subject matter announced in advance
# - Meetup happens at a consistent day/time/location
# - Announce what bar we will go to in advance of the meetup

# %% [markdown]
# # Presentations
#
# ### We are at the mercy of volunteers
# - Doesn't always work, sometimes we're scrambling at the last minute
# - Can we have a few regular attendees on standby ready to present?
# - Plan out our presentation calendar months in advance?
#
# ### Make it easier to be a presenter
# - Don't have to do all of the work preparing
# - Coaching + help for novice presenters
# - Presentation templates
#
# ### Make it easier to refer to presentations
# - Github repo for presentation materials
# - Particularily useful presentations can get re-presented every year or two
# - Jupyter notebooks are easier for us to refer to later
#
# ### Tired: One person prepares & presents
# ![Do not want!](Vader-Do-Not-Want_1200_709_81_s.jpg "Do not want!")
#
# ### Wired: Make it easier to create presentations
# - Group members suggest topics that would be most useful
# - Group members help outline the material
# - Better collaboration tools
# - Let's create a "how to present" document / guidelines
#
# ### https://github.com/austin-python/APUG_presentations
# - Let's get you set up as project members tonight!
# ![Github Octocat](Happy-Octocat.png "Github Octocat")

# %% [markdown]
# # WYSK = What You Should Know series
#
# - Debugging / Linting / Winpdb
# - Docker vs Virtualbox vs Ansible vs Saltstack
# - Type safety (has changed a lot from Python 3.6 on)
# - Lambda functions
# - Functional programming
# - DevOps
# - Important to know Python libraries
#     * Pandas
#     * Flask
#     * Numpy
#     * TensorFlow
#     * Beautiful Soup
#     * Bokeh
#     * NLTK
#     * scipy
#     * sklearn
#     * Mypy
#     * Black
#     * Matplotlib
#     * PyTest
#     * Click
# - Pickling
# - Machine Learning
# - Testing / QA / Test automation / Selenium
# - AWS / Ansible / Saltstack / Terraform
# - Vagrant
# - TravisCI / Circle CI / Jenkins
# - Mathematics that programmers should know
#     * Statistics
#     * others?
# - Magic methods / dunder methods
# - Porting python2 to python3
# - Intro to other languages worth knowing a little about
#     * GoLang
#     * R
#     * C / C++
#     * Node
#     * others?
# - AsyncIO
# - Cython
# - How to help a beginner programmer
# - Key python standard library things we all should know
#     * itertools
#     * lots of other examples
#     * we all could benefit from digging into corners of the standard library we haven't used
# - Databases
#     * Intro to the most important ones sqllite / Postres / MySQL / NoSQL
#     * SQLAlchemy
#     * How to use if you haven't used before
# - decorators / generators / partials / functools / async
# - git, git beyond the basics
# - virtualenv / venv / packaging
# - How to contribute to an open source project
# - Container myths
# - Jupyter notebooks
# - Documentation
# - Continuous integration
# - How to take your programming skills to the next level

# %% [markdown]
# # Sponsorship
#
# ### This meetup has been great about providing food + drinks
# - Typically costs about \$500 for food, and \$300 for drinks
# - Sometimes companies sponsor because they are hiring
# - Sometimes companies sponsor for the community credit
# - Sometimes individuals reach into their own pockets
#
# ### We need to expand our circle of sponsors
# - Do a better job of thanking our sponsors
# - Best practices = figure out how other meetups do it
# - Make it much easier to describe the benefits of sponorship
#
# ### Need some volunteers
# - Write 500 words on sponsorship
# - Be the point of contact for sponsors
# - Be in charge of ordering food (estimate quantities, place order, and collect from sponsor)
#
# ### Who is tonight's sponsor?
# ![Anaconda feeding us again](Anaconda_stacked_RGB_crop.jpg "Anaconda feeds us again")
#
# ### What positions do they have open?
# https://www.anaconda.com/anaconda-careers/#careers-positions
